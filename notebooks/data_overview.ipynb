# %%
import pandas as pd

# %%
data = pd.read_csv("../dataset/data.csv")

# %%
data.shape
# Out:
# (1000, 28)

# %%
data.columns.to_list()
# Out:
# ['Customer_ID',
#  'Age',
#  'Gender',
#  'Income_Level',
#  'Marital_Status',
#  'Education_Level',
#  'Occupation',
#  'Location',
#  'Purchase_Category',
#  'Purchase_Amount',
#  'Frequency_of_Purchase',
#  'Purchase_Channel',
#  'Brand_Loyalty',
#  'Product_Rating',
#  'Time_Spent_on_Product_Research(hours)',
#  'Social_Media_Influence',
#  'Discount_Sensitivity',
#  'Return_Rate',
#  'Customer_Satisfaction',
#  'Engagement_with_Ads',
#  'Device_Used_for_Shopping',
#  'Payment_Method',
#  'Time_of_Purchase',
#  'Discount_Used',
#  'Customer_Loyalty_Program_Member',
#  'Purchase_Intent',
#  'Shipping_Preference',
#  'Time_to_Decision']

# %%
data.isnull().sum()
# Out:
# Customer_ID                                0
# Age                                        0
# Gender                                     0
# Income_Level                               0
# Marital_Status                             0
# Education_Level                            0
# Occupation                                 0
# Location                                   0
# Purchase_Category                          0
# Purchase_Amount                            0
# Frequency_of_Purchase                      0
# Purchase_Channel                           0
# Brand_Loyalty                              0
# Product_Rating                             0
# Time_Spent_on_Product_Research(hours)      0
# Social_Media_Influence                   247
# Discount_Sensitivity                       0
# Return_Rate                                0
# Customer_Satisfaction                      0
# Engagement_with_Ads                      256
# Device_Used_for_Shopping                   0
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dtypes
# Out:
# Customer_ID                                  str
# Age                                        int64
# Gender                                       str
# Income_Level                                 str
# Marital_Status                               str
# Education_Level                              str
# Occupation                                   str
# Location                                     str
# Purchase_Category                            str
# Purchase_Amount                              str
# Frequency_of_Purchase                      int64
# Purchase_Channel                             str
# Brand_Loyalty                              int64
# Product_Rating                             int64
# Time_Spent_on_Product_Research(hours)    float64
# Social_Media_Influence                       str
# Discount_Sensitivity                         str
# Return_Rate                                int64
# Customer_Satisfaction                      int64
# ...

# %%
columns = ['Customer_ID', 'Age', 'Gender', 'Income_Level', 'Marital_Status',
       'Education_Level', 'Occupation', 'Location', 'Purchase_Category',
       'Purchase_Amount', 'Frequency_of_Purchase', 'Purchase_Channel',
       'Brand_Loyalty', 'Product_Rating',
       'Time_Spent_on_Product_Research(hours)', 'Social_Media_Influence',
       'Discount_Sensitivity', 'Return_Rate', 'Customer_Satisfaction',
       'Engagement_with_Ads', 'Device_Used_for_Shopping', 'Payment_Method',
       'Time_of_Purchase', 'Discount_Used', 'Customer_Loyalty_Program_Member',
       'Purchase_Intent', 'Shipping_Preference', 'Time_to_Decision']

# %%
data.fillna({'Engagement_with_Ads': 'Unknown'}, inplace=True)
data.fillna({'Social_Media_Influence': 'Unknown'}, inplace=True)
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation    Location     Purchase_Category Purchase_Amount  ...  \
# ...

# %%
data.isna().sum()
# Out:
# Customer_ID                              0
# Age                                      0
# Gender                                   0
# Income_Level                             0
# Marital_Status                           0
# Education_Level                          0
# Occupation                               0
# Location                                 0
# Purchase_Category                        0
# Purchase_Amount                          0
# Frequency_of_Purchase                    0
# Purchase_Channel                         0
# Brand_Loyalty                            0
# Product_Rating                           0
# Time_Spent_on_Product_Research(hours)    0
# Social_Media_Influence                   0
# Discount_Sensitivity                     0
# Return_Rate                              0
# Customer_Satisfaction                    0
# Engagement_with_Ads                      0
# Device_Used_for_Shopping                 0
# Payment_Method                           0
# ...

# %%
data['Time_of_Purchase'] = pd.to_datetime(data['Time_of_Purchase'])

# %%
data['Purchase_Amount'] = data['Purchase_Amount'].str.replace('$', '', regex=False)
data['Purchase_Amount'] = pd.to_numeric(data['Purchase_Amount'])

# %%
data.dtypes
# Out:
# Customer_ID                                         str
# Age                                               int64
# Gender                                              str
# Income_Level                                        str
# Marital_Status                                      str
# Education_Level                                     str
# Occupation                                          str
# Location                                            str
# Purchase_Category                                   str
# Purchase_Amount                                 float64
# Frequency_of_Purchase                             int64
# Purchase_Channel                                    str
# Brand_Loyalty                                     int64
# Product_Rating                                    int64
# Time_Spent_on_Product_Research(hours)           float64
# Social_Media_Influence                              str
# Discount_Sensitivity                                str
# ...

# %%
for col in columns:
    if (data[col].dtype == "int64") or (data[col].dtype == "float64"):
        print(f"{col} max: {data[col].max()}")
        print(f"{col} min: {data[col].min()}")
# Out:
# Age max: 50
# Age min: 18
# Purchase_Amount max: 498.33
# Purchase_Amount min: 50.71
# Frequency_of_Purchase max: 12
# Frequency_of_Purchase min: 2
# Brand_Loyalty max: 5
# Brand_Loyalty min: 1
# Product_Rating max: 5
# Product_Rating min: 1
# Time_Spent_on_Product_Research(hours) max: 2.0
# Time_Spent_on_Product_Research(hours) min: 0.0
# Return_Rate max: 2
# Return_Rate min: 0
# Customer_Satisfaction max: 10
# Customer_Satisfaction min: 1
# Time_to_Decision max: 14
# Time_to_Decision min: 1

# %%
data.rename(columns={'Time_Spent_on_Product_Research(hours)': 'Time_Spent_on_Product_Research'}, inplace=True)

# %%
data['Discount_Used'].value_counts()
data['Customer_Loyalty_Program_Member'].value_counts()
# Out:
# Customer_Loyalty_Program_Member
# False    509
# True     491
# Name: count, dtype: int64

# %%
data.to_csv("../dataset/data_clean.csv")
